# %%
# %load_ext autoreload
# %autoreload 2
import xarray as xr
from src.trmm import *
from src.regions import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
region = cio_region()
crh = load_region_var(region.name, 'crh')
pr = load_region_var(region.name, 'total_precip')
N = load_region_var(region.name, 'total_pixels')
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File ~/miniconda3/envs/extreme_precipitation_in_gpm/lib/python3.12/site-packages/xarray/core/concat.py:254, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs, create_index_for_new_dim)
#     253 try:
# --> 254     first_obj, objs = utils.peek_at(objs)
#     255 except StopIteration:
#
# File ~/miniconda3/envs/extreme_precipitation_in_gpm/lib/python3.12/site-packages/xarray/core/utils.py:200, in peek_at(iterable)
#     199 gen = iter(iterable)
# --> 200 peek = next(gen)
#     201 return peek, itertools.chain([peek], gen)
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 region = cio_region()
# ...

# %%
crh
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:  (scenes: 138114)
# Dimensions without coordinates: scenes
# Data variables:
#     Iorg     (scenes) float64 1MB 0.7887 0.8716 0.9427 ... 0.828 0.5527 0.756
