# %%
#
# In this notebook we examine how the GPM swath samples the distribution of systems. 
#
# %load_ext autoreload
# %autoreload 2
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import binned_statistic
from src.mcs import *
from src.plotting import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ds = load_mcs()
pf_areas = ds.pf_area.data.ravel()
non_nan_id = np.logical_not(np.isnan(pf_areas))
pf_areas = pf_areas[np.where(non_nan_id)]
area_bins = np.logspace(3, 5, 20)

counts = binned_statistic(
    pf_areas, 
    None, 
    bins=area_bins, 
    staticstic='count'
).statistic

plt.plot(
    
)

plt.xscale('log')
plt.yscale('log')

# %%
 ds.pf_area
# Out:
# <xarray.DataArray 'pf_area' (tracks: 32682, times: 400, nmaxpf: 3)> Size: 157MB
# array([[[339600.,  11000.,   2100.],
#         [328400.,  18100.,   5500.],
#         ...,
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan]],
#
#        [[ 66000.,  25800.,   4700.],
#         [116300.,  28000.,     nan],
#         ...,
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan]],
#
#        ...,
#
#        [[ 46000.,   7400.,     nan],
#         [ 48600.,   3200.,   1500.],
#         ...,
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan]],
#
#        [[ 23000.,     nan,     nan],
#         [ 21000.,   7000.,   1000.],
#         ...,
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan]]], dtype=float32)
# Coordinates:
#   * tracks   (tracks) int64 261kB 0 1 2 3 4 5 ... 32677 32678 32679 32680 32681
#   * times    (times) int64 3kB 0 1 2 3 4 5 6 7 ... 393 394 395 396 397 398 399
# ...
