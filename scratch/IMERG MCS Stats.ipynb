# %%
# Analyzes role of morphology in modulating MCS preciptiation
# %load_ext autoreload
# %autoreload 2
import xarray as xr
from src.mcs import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mcs_all = load_mcs()

# %%
mcs
# Out:
# <xarray.Dataset> Size: 21GB
# Dimensions:                  (tracks: 32682, times: 400, mergers: 50, nmaxpf: 3)
# Coordinates:
#   * tracks                   (tracks) int64 261kB 0 1 2 3 ... 32679 32680 32681
#   * times                    (times) int64 3kB 0 1 2 3 4 ... 395 396 397 398 399
#   * mergers                  (mergers) int64 400B 0 1 2 3 4 5 ... 45 46 47 48 49
#   * nmaxpf                   (nmaxpf) int64 24B 0 1 2
# Data variables: (12/55)
#     track_duration           (tracks, times) float64 105MB nan nan ... nan nan
#     start_status             (tracks, times) float64 105MB nan nan ... nan nan
#     end_status               (tracks, times) float64 105MB nan nan ... nan nan
#     start_basetime           (tracks, times) datetime64[ns] 105MB NaT ... NaT
#     end_basetime             (tracks, times) datetime64[ns] 105MB NaT ... NaT
#     start_split_cloudnumber  (tracks, times) float64 105MB nan nan ... nan nan
#     ...                       ...
# ...

# %%
mcs_all
# Out:
# <xarray.Dataset> Size: 20GB
# Dimensions:                  (tracks: 32682, times: 400, mergers: 50, nmaxpf: 3)
# Coordinates:
#   * tracks                   (tracks) int64 261kB 0 1 2 3 ... 32679 32680 32681
#   * times                    (times) int64 3kB 0 1 2 3 4 ... 395 396 397 398 399
#   * mergers                  (mergers) int64 400B 0 1 2 3 4 5 ... 45 46 47 48 49
#   * nmaxpf                   (nmaxpf) int64 24B 0 1 2
# Data variables: (12/55)
#     track_duration           (tracks) int32 131kB ...
#     start_status             (tracks) float64 261kB ...
#     end_status               (tracks) float64 261kB ...
#     start_basetime           (tracks) datetime64[ns] 261kB ...
#     end_basetime             (tracks) datetime64[ns] 261kB ...
#     start_split_cloudnumber  (tracks) float64 261kB ...
#     ...                       ...
#     pf_mcsstatus             (tracks, times) float64 105MB ...
#     movement_distance        (tracks, times) float32 52MB ...
# ...
