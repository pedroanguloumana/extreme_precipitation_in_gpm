# %%
# %load_ext autoreload
# %autoreload 2
import xarray as xr
from IPython.display import clear_output
from src.radar import *
from src.regions import *
from src.pf_stats import *

# %%
#
# Check that the radar and stats files are the same size
#
for year in range(2015, 2025):
    for month in range(1, 13):
        clear_output()
        print(f'{year}_{month}')
        stats_file = f'/Users/pedro/extreme_precipitation_in_gpm/data/precipitation_feature_database/gpm_pf_stats.CIO.{year}.{month:02d}.csv'
        radar_file = f'/Users/pedro/extreme_precipitation_in_gpm/data/precipitation_feature_database/gpm_pf_radar_profiles.CIO.{year}.{month:02d}.nc'

        stats = pd.read_csv(stats_file)
        radar = xr.open_dataset(radar_file)

        assert stats.shape[0]==radar.features.size
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
region.name
# Out:
# 'CIO'

# %%
region = cio_region()
files = get_radar_files(region)
ds = xr.open_mfdataset(files, combine='nested', concat_dim='features')
fname = '/Users/pedro/extreme_precipitation_in_gpm/data/precipitation_feature_database/merged.gpm_pf_radar.{region.name}.nc'
ds.to_netcdf(fname)

# %%
xr.open_dataset(fname)
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:                           (features: 657137, alt: 176)
# Coordinates:
#     time                              (features) datetime64[ns] 5MB ...
#   * alt                               (alt) float32 704B 0.0 0.125 ... 21.88
#   * features                          (features) <U68 179MB 'pf_0001.GPM2Ku7_...
# Data variables:
#     mean_refl                         (features, alt) float64 925MB ...
#     largest_5mmhr_cluster_refl_conn8  (features, alt) float64 925MB ...
#     largest_5mmhr_cluster_refl_conn4  (features, alt) float64 925MB ...
#     max_precip_refl                   (features, alt) float64 925MB ...
